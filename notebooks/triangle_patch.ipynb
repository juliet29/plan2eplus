# %%
import shapely
from matplotlib.lines import Line2D
from replan2eplus.geometry.coords import Coord
from replan2eplus.visuals.transformations import split_coords
from replan2eplus.visuals.arrow import create_triangle_patch, line_to_coords
from matplotlib.patches import Polygon
import matplotlib.pyplot as plt

# %%
coord_a = Coord(1,1)
coord_b = Coord(3,3)
line_ = Line2D(*split_coords([coord_a, coord_b]))

line_

# %%
EXPANSION_FACTOR=1.3
coords = line_to_coords(line_)
line = shapely.LineString([i.as_tuple for i in coords])

dist_along = (line.length / 2) * EXPANSION_FACTOR
p0 = line.interpolate(-dist_along)
shapely.GeometryCollection([line, p0, line.centroid])
# Out:
# <GEOMETRYCOLLECTION (LINESTRING (1 1, 3 3), POINT (1.7 1.7), POINT (2 2))>

# %%
poly = create_triangle_patch(line_, 1.2, True)
fig, axes = plt.subplots(figsize=(12, 8))

axes.set_xlim(0,10)
axes.set_ylim(0,10)
axes.add_line(line_)
axes.add_patch(poly)

# %%
import math

# %%
math.copysign(0, -3000)
# Out:
# -0.0

# %%
assert 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 assert 0
#
# AssertionError:

# %%
import array


array.array([1,2,3])/7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import array
# ----> 4 array.array([1,2,3])/7
#
# TypeError: array() argument 1 must be a unicode character, not list
